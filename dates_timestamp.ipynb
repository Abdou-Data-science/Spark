# %%
from pyspark.sql import SparkSession

# %%
from pyspark.sql.functions import to_date, dayofmonth,hour,dayofyear,month,year,format_number,date_format

# %%
spark = SparkSession.builder.appName('dates').getOrCreate()

# %%
df = spark.read.csv('data/Python-and-Spark-for-Big-Data-master/Spark_DataFrames/appl_stock.csv', header=True, inferSchema=True)

# %%
df.show()
# Out:
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# |      Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# |2010-01-04|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|
# |2010-01-05|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|
# |2010-01-06|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|
# |2010-01-07|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|
# |2010-01-08|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|
# ...

# %%
df.select(['date', 'Open']).show()
# Out:
# +----------+------------------+
# |      date|              Open|
# +----------+------------------+
# |2010-01-04|        213.429998|
# |2010-01-05|        214.599998|
# |2010-01-06|        214.379993|
# |2010-01-07|            211.75|
# |2010-01-08|        210.299994|
# |2010-01-11|212.79999700000002|
# |2010-01-12|209.18999499999998|
# |2010-01-13|        207.870005|
# |2010-01-14|210.11000299999998|
# |2010-01-15|210.92999500000002|
# |2010-01-19|        208.330002|
# |2010-01-20|        214.910006|
# |2010-01-21|        212.079994|
# |2010-01-22|206.78000600000001|
# |2010-01-25|202.51000200000001|
# |2010-01-26|205.95000100000001|
# |2010-01-27|        206.849995|
# |2010-01-28|        204.930004|
# |2010-01-29|        201.079996|
# |2010-02-01|192.36999699999998|
# +----------+------------------+
# only showing top 20 rows

# %%
df.withColumn('test_date', year('Date')).show()
# Out:
# +----------+------------------+------------------+------------------+------------------+---------+------------------+---------+
# |      Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|test_date|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+---------+
# |2010-01-04|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|     2010|
# |2010-01-05|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|     2010|
# |2010-01-06|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|     2010|
# |2010-01-07|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|     2010|
# ...
